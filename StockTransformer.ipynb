# %%
# pip uninstall torch torchvision torchaudio -y

# %%
# pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
import torch

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"Device name: {torch.cuda.get_device_name(0)}")
else:
    print("CUDA is not available.")
# Out:
# PyTorch version: 2.5.0+cu118
# CUDA available: True
# Device name: NVIDIA GeForce RTX 2060

# %%
# !pip install yfinance

# %%
import math
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import yfinance as yf

# %%
class TimeSeriesTransformer(nn.Module):
    def __init__(self, input_dim, d_model, nhead, num_layers, dim_feedforward, dropout=0.1):
        super(TimeSeriesTransformer, self).__init__()
        self.model_type = 'Transformer'
        self.d_model = d_model

        # Set batch_first=True here
        self.positional_encoding = PositionalEncoding(d_model, dropout, batch_first=True)
        encoder_layers = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward, dropout, batch_first=True)
        self.transformer_encoder = nn.TransformerEncoder(encoder_layers, num_layers)

        self.input_projection = nn.Linear(input_dim, d_model)
        self.decoder = nn.Linear(d_model, 1)

    def forward(self, src):
        # Now src shape should be [batch_size, sequence_length, input_dim]
        src = self.input_projection(src) * math.sqrt(self.d_model)
        src = self.positional_encoding(src)
        output = self.transformer_encoder(src)
        output = output.mean(dim=1)  # Global average pooling over the sequence length
        output = self.decoder(output)
        return output

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, dropout=0.1, max_len=5000, batch_first=False):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)
        self.batch_first = batch_first
        
        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float32).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).to(torch.float32) * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        if d_model % 2 == 1:
            pe[:, 1::2] = torch.cos(position * div_term[:-1])
        else:
            pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)  # Shape: [1, max_len, d_model]
        self.register_buffer('pe', pe)

    def forward(self, x):
        # x shape: [batch_size, sequence_length, d_model]
        if self.batch_first:
            x = x + self.pe[:, :x.size(1)]
        else:
            x = x + self.pe[:x.size(0)]
        return self.dropout(x)

# %%
def calculate_bollinger_bands(data, window=10, num_of_std=2):
    """Calculate Bollinger Bands"""
    rolling_mean = data.rolling(window=window).mean()
    rolling_std = data.rolling(window=window).std()
    upper_band = rolling_mean + (rolling_std * num_of_std)
    lower_band = rolling_mean - (rolling_std * num_of_std)
    return upper_band, lower_band

def calculate_rsi(data, window=10):
    """Calculate Relative Strength Index"""
    delta = data.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=window, min_periods=1).mean()
    avg_loss = loss.rolling(window=window, min_periods=1).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def calculate_roc(data, periods=10):
    """Calculate Rate of Change."""
    roc = ((data - data.shift(periods)) / data.shift(periods)) * 100
    return roc

# %%
tickers = ['META', 'AAPL', 'MSFT', 'AMZN', 'GOOG']

# Download historical data for each ticker
ticker_data_frames = []
stats = {}

for ticker in tickers:
    print(f"Processing {ticker}...")
    # Download historical data
    data = yf.download(ticker, period="5y", interval="1d")
    
    if data.empty:
        print(f"No data found for {ticker}. Skipping.")
        continue  # Skip to the next ticker if no data is found

    # Use 'Open' and 'Close' prices, converting to Series
    open_price = data['Open'].squeeze()
    close_price = data['Close'].squeeze()
    high = data['High'].squeeze()
    low = data['Low'].squeeze()
    volume = data['Volume'].squeeze()

    # Calculate additional indicators if needed
    daily_return = close_price.pct_change()
    moving_avg_10 = close_price.rolling(window=10).mean()
    moving_avg_30 = close_price.rolling(window=30).mean()
    bollinger_upper, bollinger_lower = calculate_bollinger_bands(close_price)
    rsi = calculate_rsi(close_price)
    roc = calculate_roc(close_price)

    # Create a dictionary of variables
    variables = {
        ticker + '_open': open_price,
        ticker + '_close': close_price,
        ticker + '_high': high,
        ticker + '_low': low,
        ticker + '_volume': volume,
        ticker + '_daily_return': daily_return,
        ticker + '_ma10': moving_avg_10,
        ticker + '_ma30': moving_avg_30,
        ticker + '_bollinger_upper': bollinger_upper,
        ticker + '_bollinger_lower': bollinger_lower,
        ticker + '_rsi': rsi,
        ticker + '_roc': roc,
    }

    # Verify that all variables are Series
    for name, var in variables.items():
        print(f"{name}: type={type(var)}, length={len(var)}")

    # Create DataFrame from the variables dictionary
    ticker_df = pd.DataFrame(variables)

    # Handle missing values
    ticker_df.dropna(inplace=True)

    if ticker_df.empty:
        print(f"No data left for {ticker} after dropping NaNs.")
        continue

    # Calculate mean and std for normalization
    MEAN = ticker_df.mean()
    STD = ticker_df.std()

    # Store stats for each feature
    for column in MEAN.index:
        stats[f"{column}_mean"] = MEAN[column]
        stats[f"{column}_std"] = STD[column]

    # Normalize the data
    ticker_df = (ticker_df - MEAN) / STD

    ticker_data_frames.append(ticker_df)
    print(f"Finished processing {ticker}.")
# Out:
# [*********************100%***********************]  1 of 1 completed
# Processing META...
# META_open: type=<class 'pandas.core.series.Series'>, length=1258
# META_close: type=<class 'pandas.core.series.Series'>, length=1258
# META_high: type=<class 'pandas.core.series.Series'>, length=1258
# META_low: type=<class 'pandas.core.series.Series'>, length=1258
# META_volume: type=<class 'pandas.core.series.Series'>, length=1258
# META_daily_return: type=<class 'pandas.core.series.Series'>, length=1258
# META_ma10: type=<class 'pandas.core.series.Series'>, length=1258
# META_ma30: type=<class 'pandas.core.series.Series'>, length=1258
# META_bollinger_upper: type=<class 'pandas.core.series.Series'>, length=1258
# META_bollinger_lower: type=<class 'pandas.core.series.Series'>, length=1258
# META_rsi: type=<class 'pandas.core.series.Series'>, length=1258
# META_roc: type=<class 'pandas.core.series.Series'>, length=1258
# Finished processing META.
# Processing AAPL...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AAPL_open: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_close: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_high: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_low: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_volume: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_daily_return: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_ma10: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_ma30: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_bollinger_upper: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_bollinger_lower: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_rsi: type=<class 'pandas.core.series.Series'>, length=1258
# AAPL_roc: type=<class 'pandas.core.series.Series'>, length=1258
# Finished processing AAPL.
# Processing MSFT...
# MSFT_open: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_close: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_high: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_low: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_volume: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_daily_return: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_ma10: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_ma30: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_bollinger_upper: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_bollinger_lower: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_rsi: type=<class 'pandas.core.series.Series'>, length=1258
# MSFT_roc: type=<class 'pandas.core.series.Series'>, length=1258
# Finished processing MSFT.
# Processing AMZN...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# AMZN_open: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_close: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_high: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_low: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_volume: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_daily_return: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_ma10: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_ma30: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_bollinger_upper: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_bollinger_lower: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_rsi: type=<class 'pandas.core.series.Series'>, length=1258
# AMZN_roc: type=<class 'pandas.core.series.Series'>, length=1258
# Finished processing AMZN.
# Processing GOOG...
# GOOG_open: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_close: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_high: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_low: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_volume: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_daily_return: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_ma10: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_ma30: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_bollinger_upper: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_bollinger_lower: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_rsi: type=<class 'pandas.core.series.Series'>, length=1258
# GOOG_roc: type=<class 'pandas.core.series.Series'>, length=1258
# Finished processing GOOG.

# %%
# Combine all ticker data into a single DataFrame
df = pd.concat(ticker_data_frames, axis=1)

# Handle any remaining missing values
df.dropna(inplace=True)

# %%
SEQUENCE_LEN = 30  # Use the past 30 days to predict the next day's closing price

def create_sequences(data, labels, sequence_length=SEQUENCE_LEN):
    sequences = []
    lab = []
    data_size = len(data)

    for i in range(data_size - sequence_length):
        sequences.append(data[i:i + sequence_length])
        lab.append(labels[i + sequence_length])  # Predict the next day's value

    return np.array(sequences), np.array(lab)

# %%
sequences_list = []
labels_list = []

for ticker in tickers:
    # Extract features for the ticker
    features = df.filter(like=ticker).values

    # The label is the next day's closing price (unscaled)
    close_price = df[ticker + '_close'].values
    mean_close = stats[ticker + '_close_mean']
    std_close = stats[ticker + '_close_std']

    # Unscale the closing price for labels
    # unscaled_close = close_price * std_close + mean_close <- was causing issues due to inconsistent normalisation

    # Create sequences and labels
    ticker_sequences, ticker_labels = create_sequences(features, close_price)

    sequences_list.append(ticker_sequences)
    labels_list.append(ticker_labels)

# Combine data from all tickers
all_sequences = np.concatenate(sequences_list)
all_labels = np.concatenate(labels_list)

# Reshape sequences to [num_samples, seq_len, num_features]
# For PyTorch, we need to transpose to [seq_len, num_samples, num_features]
# all_sequences = all_sequences.transpose(1, 0, 2)

# %%
print(f"all_sequences.shape: {all_sequences.shape}")
print(f"all_labels.shape: {all_labels.shape}")
# Out:
# all_sequences.shape: (5995, 30, 12)
# all_labels.shape: (5995,)

# %%
# split data

# %%
class TimeSeriesDataset(Dataset):
    def __init__(self, sequences, labels):
        self.sequences = sequences.astype(np.float32)  # [num_samples, sequence_length, num_features]
        self.labels = labels.astype(np.float32)        # [num_samples]

    def __len__(self):
        return self.sequences.shape[0]  # num_samples

    def __getitem__(self, idx):
        sequence = self.sequences[idx]  # Shape: [sequence_length, num_features]
        label = self.labels[idx]
        return sequence, label


# Split data into training, validation, and test sets
print(all_sequences.shape)
dataset_size = all_sequences.shape[0]
train_size = int(0.8 * dataset_size)
val_size = int(0.1 * dataset_size)
test_size = dataset_size - train_size - val_size
print(f"Train size: {train_size}, Validation size: {val_size}, Test size: {test_size}")

indices = np.random.permutation(dataset_size)
train_indices = indices[:train_size]
val_indices = indices[train_size:train_size+val_size]
test_indices = indices[train_size+val_size:]
print(f"Train indices: {len(train_indices)}, Validation indices: {len(val_indices)}, Test indices: {len(test_indices)}")

train_dataset = TimeSeriesDataset(all_sequences[train_indices, :, :], all_labels[train_indices])
val_dataset = TimeSeriesDataset(all_sequences[val_indices, :, :], all_labels[val_indices])
test_dataset = TimeSeriesDataset(all_sequences[test_indices, :, :], all_labels[test_indices])

# Create DataLoaders
BATCH_SIZE = 64

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE)
# Out:
# (5995, 30, 12)
# Train size: 4796, Validation size: 599, Test size: 600
# Train indices: 4796, Validation indices: 599, Test indices: 600

# %%
class EarlyStopping:
    def __init__(self, patience=10, verbose=False, delta=0, path='checkpoint.pth'):
        """
        Args:
            patience (int): How long to wait after last improvement.
            verbose (bool): If True, prints messages when an improvement is made.
            delta (float): Minimum change to qualify as an improvement.
            path (str): Path to save the model checkpoint.
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path

    def __call__(self, val_loss, model):
        # print(val_loss)
        score = val_loss  # We want to minimize validation loss
        # print(f'\nself.best_score {self.best_score} \ncur score {score} \nand delta {self.delta}')

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)

        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}, current best is {self.best_score}')

            if self.counter >= self.patience:
                self.early_stop = True

        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        """Saves model when directional accuracy increases."""
        if self.verbose:
            print(f'Validation accuracy increased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
input_dim = all_sequences.shape[2]  # Number of features
d_model = 64
nhead = 4
num_layers = 6
dim_feedforward = 128
dropout = 0.1

model = TimeSeriesTransformer(input_dim, d_model, nhead, num_layers, dim_feedforward, dropout)
model = model.to(device)

criterion = nn.L1Loss()

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

optimizer = optim.Adam(model.parameters(), lr=0.002)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.9, patience=20, verbose=True)
# Out:
# C:\Users\awsul\anaconda3\Lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
EPOCHS = 10000

# Initialize EarlyStopping object
early_stopping = EarlyStopping(patience=100, verbose=True, path='best_model.pth')

for epoch in range(EPOCHS):
    # Training 
    model.train()
    train_loss = 0.0
    for sequences, labels in train_loader:
        sequences = sequences.to(device)  # [batch_size, sequence_length, num_features]
        labels = labels.to(device)        # [batch_size]

        optimizer.zero_grad()
        outputs = model(sequences)        # [batch_size, 1]
        outputs = outputs.squeeze()       # [batch_size]

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item() * labels.size(0)

    avg_train_loss = train_loss / len(train_loader.dataset)

    # Validation 
    model.eval()
    val_loss = 0.0
    val_directional_accuracy = 0.0
    with torch.no_grad():
        for sequences, labels in val_loader:
            sequences = sequences.to(device)
            labels = labels.to(device)

            outputs = model(sequences)
            outputs = outputs.squeeze()

            loss = criterion(outputs, labels)
            val_loss += loss.item() * labels.size(0)

            # Compute directional accuracy
            prev_close = sequences[:, -1, 0]
            true_diff = labels - prev_close
            pred_diff = outputs - prev_close
            correct_direction = torch.eq(torch.sign(true_diff), torch.sign(pred_diff)).float()
            val_directional_accuracy += correct_direction.sum().item()

    avg_val_loss = val_loss / len(val_loader.dataset)
    avg_val_accuracy = val_directional_accuracy / len(val_loader.dataset)

    print(f"Epoch {epoch+1}/{EPOCHS}, "
          f"Train Loss: {avg_train_loss:.4f}, "
          f"Val Loss: {avg_val_loss:.4f}, "
          f"Val Directional Accuracy: {avg_val_accuracy:.4f} \n")

    # Early stopping
    early_stopping(avg_val_accuracy, model)

    if early_stopping.early_stop:
        print("Early stopping triggered. Training stopped.")
        break

    model.load_state_dict(torch.load('best_model.pth'))
# Out:
# Epoch 1/10000, Train Loss: 0.1232, Val Loss: 0.0851, Val Directional Accuracy: 0.6144
#
# Validation accuracy increased (inf --> 0.614357).  Saving model...
# C:\Users\awsul\AppData\Local\Temp\ipykernel_15296\854853025.py:63: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_model.pth'))
# Epoch 2/10000, Train Loss: 0.0826, Val Loss: 0.0703, Val Directional Accuracy: 0.6544
#
# Validation accuracy increased (0.614357 --> 0.654424).  Saving model...
# Epoch 3/10000, Train Loss: 0.0838, Val Loss: 0.0634, Val Directional Accuracy: 0.6444
#
# EarlyStopping counter: 1 out of 100, current best is 0.654424040066778
# Epoch 4/10000, Train Loss: 0.0890, Val Loss: 0.0688, Val Directional Accuracy: 0.6694
#
# Validation accuracy increased (0.654424 --> 0.669449).  Saving model...
# Epoch 5/10000, Train Loss: 0.0833, Val Loss: 0.0692, Val Directional Accuracy: 0.6511
#
# EarlyStopping counter: 1 out of 100, current best is 0.669449081803005
# Epoch 6/10000, Train Loss: 0.0895, Val Loss: 0.0899, Val Directional Accuracy: 0.6144
#
# EarlyStopping counter: 2 out of 100, current best is 0.669449081803005
# Epoch 7/10000, Train Loss: 0.0839, Val Loss: 0.0761, Val Directional Accuracy: 0.6611
#
# EarlyStopping counter: 3 out of 100, current best is 0.669449081803005
# Epoch 8/10000, Train Loss: 0.0891, Val Loss: 0.0837, Val Directional Accuracy: 0.6277
#
# EarlyStopping counter: 4 out of 100, current best is 0.669449081803005
# Epoch 9/10000, Train Loss: 0.0809, Val Loss: 0.0844, Val Directional Accuracy: 0.5943
#
# EarlyStopping counter: 5 out of 100, current best is 0.669449081803005
# Epoch 10/10000, Train Loss: 0.0807, Val Loss: 0.0659, Val Directional Accuracy: 0.6494
#
# EarlyStopping counter: 6 out of 100, current best is 0.669449081803005
# Epoch 11/10000, Train Loss: 0.0836, Val Loss: 0.0617, Val Directional Accuracy: 0.6878
#
# Validation accuracy increased (0.669449 --> 0.687813).  Saving model...
# Epoch 12/10000, Train Loss: 0.0858, Val Loss: 0.0736, Val Directional Accuracy: 0.6511
#
# EarlyStopping counter: 1 out of 100, current best is 0.6878130217028381
# Epoch 13/10000, Train Loss: 0.0817, Val Loss: 0.0974, Val Directional Accuracy: 0.5793
#
# EarlyStopping counter: 2 out of 100, current best is 0.6878130217028381
# Epoch 14/10000, Train Loss: 0.0893, Val Loss: 0.0721, Val Directional Accuracy: 0.6544
#
# EarlyStopping counter: 3 out of 100, current best is 0.6878130217028381
# Epoch 15/10000, Train Loss: 0.0827, Val Loss: 0.0796, Val Directional Accuracy: 0.6327
#
# EarlyStopping counter: 4 out of 100, current best is 0.6878130217028381
# Epoch 16/10000, Train Loss: 0.0823, Val Loss: 0.0665, Val Directional Accuracy: 0.6528
#
# EarlyStopping counter: 5 out of 100, current best is 0.6878130217028381
# Epoch 17/10000, Train Loss: 0.0857, Val Loss: 0.0880, Val Directional Accuracy: 0.6060
#
# EarlyStopping counter: 6 out of 100, current best is 0.6878130217028381
# Epoch 18/10000, Train Loss: 0.0785, Val Loss: 0.0667, Val Directional Accuracy: 0.6611
#
# EarlyStopping counter: 7 out of 100, current best is 0.6878130217028381
# Epoch 19/10000, Train Loss: 0.0870, Val Loss: 0.0822, Val Directional Accuracy: 0.6244
#
# EarlyStopping counter: 8 out of 100, current best is 0.6878130217028381
# Epoch 20/10000, Train Loss: 0.0817, Val Loss: 0.0706, Val Directional Accuracy: 0.6077
#
# EarlyStopping counter: 9 out of 100, current best is 0.6878130217028381
# Epoch 21/10000, Train Loss: 0.0895, Val Loss: 0.0711, Val Directional Accuracy: 0.6344
#
# EarlyStopping counter: 10 out of 100, current best is 0.6878130217028381
# Epoch 22/10000, Train Loss: 0.0962, Val Loss: 0.0717, Val Directional Accuracy: 0.6210
#
# EarlyStopping counter: 11 out of 100, current best is 0.6878130217028381
# Epoch 23/10000, Train Loss: 0.0857, Val Loss: 0.1062, Val Directional Accuracy: 0.6077
#
# EarlyStopping counter: 12 out of 100, current best is 0.6878130217028381
# Epoch 24/10000, Train Loss: 0.0827, Val Loss: 0.0721, Val Directional Accuracy: 0.6311
#
# EarlyStopping counter: 13 out of 100, current best is 0.6878130217028381
# Epoch 25/10000, Train Loss: 0.0807, Val Loss: 0.0689, Val Directional Accuracy: 0.6494
#
# EarlyStopping counter: 14 out of 100, current best is 0.6878130217028381
# Epoch 26/10000, Train Loss: 0.0808, Val Loss: 0.0668, Val Directional Accuracy: 0.6694
#
# EarlyStopping counter: 15 out of 100, current best is 0.6878130217028381
# Epoch 27/10000, Train Loss: 0.0832, Val Loss: 0.0697, Val Directional Accuracy: 0.6895
#
# Validation accuracy increased (0.687813 --> 0.689482).  Saving model...
# Epoch 28/10000, Train Loss: 0.0898, Val Loss: 0.0797, Val Directional Accuracy: 0.5876
#
# EarlyStopping counter: 1 out of 100, current best is 0.6894824707846411
# Epoch 29/10000, Train Loss: 0.0806, Val Loss: 0.0690, Val Directional Accuracy: 0.6644
#
# EarlyStopping counter: 2 out of 100, current best is 0.6894824707846411
# Epoch 30/10000, Train Loss: 0.0821, Val Loss: 0.0908, Val Directional Accuracy: 0.6227
#
# EarlyStopping counter: 3 out of 100, current best is 0.6894824707846411
# Epoch 31/10000, Train Loss: 0.0859, Val Loss: 0.0794, Val Directional Accuracy: 0.6244
#
# EarlyStopping counter: 4 out of 100, current best is 0.6894824707846411
# Epoch 32/10000, Train Loss: 0.0871, Val Loss: 0.0913, Val Directional Accuracy: 0.6194
#
# EarlyStopping counter: 5 out of 100, current best is 0.6894824707846411
# Epoch 33/10000, Train Loss: 0.0782, Val Loss: 0.0731, Val Directional Accuracy: 0.6260
#
# EarlyStopping counter: 6 out of 100, current best is 0.6894824707846411
# Epoch 34/10000, Train Loss: 0.0792, Val Loss: 0.0725, Val Directional Accuracy: 0.6277
#
# EarlyStopping counter: 7 out of 100, current best is 0.6894824707846411
# Epoch 35/10000, Train Loss: 0.0847, Val Loss: 0.0756, Val Directional Accuracy: 0.6277
#
# EarlyStopping counter: 8 out of 100, current best is 0.6894824707846411
# Epoch 36/10000, Train Loss: 0.0824, Val Loss: 0.0706, Val Directional Accuracy: 0.6227
#
# EarlyStopping counter: 9 out of 100, current best is 0.6894824707846411
# Epoch 37/10000, Train Loss: 0.0876, Val Loss: 0.0708, Val Directional Accuracy: 0.6628
#
# EarlyStopping counter: 10 out of 100, current best is 0.6894824707846411
# Epoch 38/10000, Train Loss: 0.0843, Val Loss: 0.0685, Val Directional Accuracy: 0.6477
#
# EarlyStopping counter: 11 out of 100, current best is 0.6894824707846411
# Epoch 39/10000, Train Loss: 0.0807, Val Loss: 0.0680, Val Directional Accuracy: 0.6511
#
# EarlyStopping counter: 12 out of 100, current best is 0.6894824707846411
# Epoch 40/10000, Train Loss: 0.0835, Val Loss: 0.0953, Val Directional Accuracy: 0.5710
#
# EarlyStopping counter: 13 out of 100, current best is 0.6894824707846411
# Epoch 41/10000, Train Loss: 0.0855, Val Loss: 0.0695, Val Directional Accuracy: 0.6561
#
# EarlyStopping counter: 14 out of 100, current best is 0.6894824707846411
# Epoch 42/10000, Train Loss: 0.0851, Val Loss: 0.0664, Val Directional Accuracy: 0.6361
#
# EarlyStopping counter: 15 out of 100, current best is 0.6894824707846411
# Epoch 43/10000, Train Loss: 0.0882, Val Loss: 0.0899, Val Directional Accuracy: 0.5760
#
# EarlyStopping counter: 16 out of 100, current best is 0.6894824707846411
# Epoch 44/10000, Train Loss: 0.0798, Val Loss: 0.0854, Val Directional Accuracy: 0.6077
#
# EarlyStopping counter: 17 out of 100, current best is 0.6894824707846411
# Epoch 45/10000, Train Loss: 0.0857, Val Loss: 0.0908, Val Directional Accuracy: 0.6110
#
# EarlyStopping counter: 18 out of 100, current best is 0.6894824707846411
# Epoch 46/10000, Train Loss: 0.0841, Val Loss: 0.0640, Val Directional Accuracy: 0.6644
#
# EarlyStopping counter: 19 out of 100, current best is 0.6894824707846411
# Epoch 47/10000, Train Loss: 0.0803, Val Loss: 0.0782, Val Directional Accuracy: 0.6177
#
# EarlyStopping counter: 20 out of 100, current best is 0.6894824707846411
# Epoch 48/10000, Train Loss: 0.0800, Val Loss: 0.0878, Val Directional Accuracy: 0.5927
#
# EarlyStopping counter: 21 out of 100, current best is 0.6894824707846411
# Epoch 49/10000, Train Loss: 0.0817, Val Loss: 0.0844, Val Directional Accuracy: 0.6144
#
# EarlyStopping counter: 22 out of 100, current best is 0.6894824707846411
# Epoch 50/10000, Train Loss: 0.0843, Val Loss: 0.0820, Val Directional Accuracy: 0.6194
#
# EarlyStopping counter: 23 out of 100, current best is 0.6894824707846411
# Epoch 51/10000, Train Loss: 0.0792, Val Loss: 0.0646, Val Directional Accuracy: 0.6477
#
# EarlyStopping counter: 24 out of 100, current best is 0.6894824707846411
# Epoch 52/10000, Train Loss: 0.0821, Val Loss: 0.0934, Val Directional Accuracy: 0.5943
#
# EarlyStopping counter: 25 out of 100, current best is 0.6894824707846411
# Epoch 53/10000, Train Loss: 0.0818, Val Loss: 0.0888, Val Directional Accuracy: 0.6110
#
# EarlyStopping counter: 26 out of 100, current best is 0.6894824707846411
# Epoch 54/10000, Train Loss: 0.0803, Val Loss: 0.0646, Val Directional Accuracy: 0.6778
#
# EarlyStopping counter: 27 out of 100, current best is 0.6894824707846411
# Epoch 55/10000, Train Loss: 0.0863, Val Loss: 0.0693, Val Directional Accuracy: 0.6327
#
# EarlyStopping counter: 28 out of 100, current best is 0.6894824707846411
# Epoch 56/10000, Train Loss: 0.0839, Val Loss: 0.0687, Val Directional Accuracy: 0.6427
#
# EarlyStopping counter: 29 out of 100, current best is 0.6894824707846411
# Epoch 57/10000, Train Loss: 0.0882, Val Loss: 0.0629, Val Directional Accuracy: 0.6728
#
# EarlyStopping counter: 30 out of 100, current best is 0.6894824707846411
# Epoch 58/10000, Train Loss: 0.0857, Val Loss: 0.0716, Val Directional Accuracy: 0.6377
#
# EarlyStopping counter: 31 out of 100, current best is 0.6894824707846411
# Epoch 59/10000, Train Loss: 0.0809, Val Loss: 0.0585, Val Directional Accuracy: 0.6928
#
# Validation accuracy increased (0.689482 --> 0.692821).  Saving model...
# Epoch 60/10000, Train Loss: 0.0843, Val Loss: 0.0689, Val Directional Accuracy: 0.6544
#
# EarlyStopping counter: 1 out of 100, current best is 0.6928213689482471
# Epoch 61/10000, Train Loss: 0.0734, Val Loss: 0.0719, Val Directional Accuracy: 0.6177
#
# EarlyStopping counter: 2 out of 100, current best is 0.6928213689482471
# Epoch 62/10000, Train Loss: 0.0834, Val Loss: 0.0752, Val Directional Accuracy: 0.6694
#
# EarlyStopping counter: 3 out of 100, current best is 0.6928213689482471
# Epoch 63/10000, Train Loss: 0.0838, Val Loss: 0.0689, Val Directional Accuracy: 0.6311
#
# EarlyStopping counter: 4 out of 100, current best is 0.6928213689482471
# Epoch 64/10000, Train Loss: 0.0853, Val Loss: 0.0647, Val Directional Accuracy: 0.6761
#
# EarlyStopping counter: 5 out of 100, current best is 0.6928213689482471
# Epoch 65/10000, Train Loss: 0.0774, Val Loss: 0.0736, Val Directional Accuracy: 0.6494
#
# EarlyStopping counter: 6 out of 100, current best is 0.6928213689482471
# Epoch 66/10000, Train Loss: 0.0850, Val Loss: 0.0993, Val Directional Accuracy: 0.6093
#
# EarlyStopping counter: 7 out of 100, current best is 0.6928213689482471
# Epoch 67/10000, Train Loss: 0.0824, Val Loss: 0.0791, Val Directional Accuracy: 0.5860
#
# EarlyStopping counter: 8 out of 100, current best is 0.6928213689482471
# Epoch 68/10000, Train Loss: 0.0779, Val Loss: 0.0656, Val Directional Accuracy: 0.6745
#
# EarlyStopping counter: 9 out of 100, current best is 0.6928213689482471
# Epoch 69/10000, Train Loss: 0.0830, Val Loss: 0.0658, Val Directional Accuracy: 0.6544
#
# EarlyStopping counter: 10 out of 100, current best is 0.6928213689482471
# Epoch 70/10000, Train Loss: 0.0825, Val Loss: 0.0720, Val Directional Accuracy: 0.6377
#
# EarlyStopping counter: 11 out of 100, current best is 0.6928213689482471
# Epoch 71/10000, Train Loss: 0.0824, Val Loss: 0.0625, Val Directional Accuracy: 0.6711
#
# EarlyStopping counter: 12 out of 100, current best is 0.6928213689482471
# Epoch 72/10000, Train Loss: 0.0804, Val Loss: 0.0783, Val Directional Accuracy: 0.6010
#
# EarlyStopping counter: 13 out of 100, current best is 0.6928213689482471
# Epoch 73/10000, Train Loss: 0.0841, Val Loss: 0.0688, Val Directional Accuracy: 0.6277
#
# EarlyStopping counter: 14 out of 100, current best is 0.6928213689482471
# Epoch 74/10000, Train Loss: 0.0842, Val Loss: 0.0699, Val Directional Accuracy: 0.6461
#
# EarlyStopping counter: 15 out of 100, current best is 0.6928213689482471
# Epoch 75/10000, Train Loss: 0.0801, Val Loss: 0.0974, Val Directional Accuracy: 0.5726
#
# EarlyStopping counter: 16 out of 100, current best is 0.6928213689482471
# Epoch 76/10000, Train Loss: 0.0877, Val Loss: 0.0672, Val Directional Accuracy: 0.6394
#
# EarlyStopping counter: 17 out of 100, current best is 0.6928213689482471
# Epoch 77/10000, Train Loss: 0.0772, Val Loss: 0.0747, Val Directional Accuracy: 0.6144
#
# EarlyStopping counter: 18 out of 100, current best is 0.6928213689482471
# Epoch 78/10000, Train Loss: 0.0820, Val Loss: 0.0887, Val Directional Accuracy: 0.6144
#
# EarlyStopping counter: 19 out of 100, current best is 0.6928213689482471
# Epoch 79/10000, Train Loss: 0.0773, Val Loss: 0.0748, Val Directional Accuracy: 0.6194
#
# EarlyStopping counter: 20 out of 100, current best is 0.6928213689482471
# Epoch 80/10000, Train Loss: 0.0836, Val Loss: 0.0624, Val Directional Accuracy: 0.6728
#
# EarlyStopping counter: 21 out of 100, current best is 0.6928213689482471
# Epoch 81/10000, Train Loss: 0.0853, Val Loss: 0.0818, Val Directional Accuracy: 0.6110
#
# EarlyStopping counter: 22 out of 100, current best is 0.6928213689482471
# Epoch 82/10000, Train Loss: 0.0844, Val Loss: 0.0686, Val Directional Accuracy: 0.6644
#
# EarlyStopping counter: 23 out of 100, current best is 0.6928213689482471
# Epoch 83/10000, Train Loss: 0.0791, Val Loss: 0.0759, Val Directional Accuracy: 0.6144
#
# EarlyStopping counter: 24 out of 100, current best is 0.6928213689482471
# Epoch 84/10000, Train Loss: 0.0799, Val Loss: 0.0752, Val Directional Accuracy: 0.6127
#
# EarlyStopping counter: 25 out of 100, current best is 0.6928213689482471
# Epoch 85/10000, Train Loss: 0.0860, Val Loss: 0.0779, Val Directional Accuracy: 0.6244
#
# EarlyStopping counter: 26 out of 100, current best is 0.6928213689482471
# Epoch 86/10000, Train Loss: 0.0771, Val Loss: 0.0683, Val Directional Accuracy: 0.6344
#
# EarlyStopping counter: 27 out of 100, current best is 0.6928213689482471
# Epoch 87/10000, Train Loss: 0.0819, Val Loss: 0.0631, Val Directional Accuracy: 0.6912
#
# EarlyStopping counter: 28 out of 100, current best is 0.6928213689482471
# Epoch 88/10000, Train Loss: 0.0744, Val Loss: 0.0708, Val Directional Accuracy: 0.6327
#
# EarlyStopping counter: 29 out of 100, current best is 0.6928213689482471
# Epoch 89/10000, Train Loss: 0.0826, Val Loss: 0.0866, Val Directional Accuracy: 0.5860
#
# EarlyStopping counter: 30 out of 100, current best is 0.6928213689482471
# Epoch 90/10000, Train Loss: 0.0801, Val Loss: 0.0632, Val Directional Accuracy: 0.6778
#
# EarlyStopping counter: 31 out of 100, current best is 0.6928213689482471
# Epoch 91/10000, Train Loss: 0.0804, Val Loss: 0.0709, Val Directional Accuracy: 0.6561
#
# EarlyStopping counter: 32 out of 100, current best is 0.6928213689482471
# Epoch 92/10000, Train Loss: 0.0823, Val Loss: 0.0888, Val Directional Accuracy: 0.5860
#
# EarlyStopping counter: 33 out of 100, current best is 0.6928213689482471
# Epoch 93/10000, Train Loss: 0.0853, Val Loss: 0.0884, Val Directional Accuracy: 0.6227
#
# EarlyStopping counter: 34 out of 100, current best is 0.6928213689482471
# Epoch 94/10000, Train Loss: 0.0792, Val Loss: 0.0795, Val Directional Accuracy: 0.5710
#
# EarlyStopping counter: 35 out of 100, current best is 0.6928213689482471
# Epoch 95/10000, Train Loss: 0.0797, Val Loss: 0.0853, Val Directional Accuracy: 0.6745
#
# EarlyStopping counter: 36 out of 100, current best is 0.6928213689482471
# Epoch 96/10000, Train Loss: 0.0864, Val Loss: 0.1098, Val Directional Accuracy: 0.5760
#
# EarlyStopping counter: 37 out of 100, current best is 0.6928213689482471
# Epoch 97/10000, Train Loss: 0.0787, Val Loss: 0.0659, Val Directional Accuracy: 0.6711
#
# EarlyStopping counter: 38 out of 100, current best is 0.6928213689482471
# Epoch 98/10000, Train Loss: 0.0832, Val Loss: 0.0781, Val Directional Accuracy: 0.6027
#
# EarlyStopping counter: 39 out of 100, current best is 0.6928213689482471
# Epoch 99/10000, Train Loss: 0.0834, Val Loss: 0.0702, Val Directional Accuracy: 0.6244
#
# EarlyStopping counter: 40 out of 100, current best is 0.6928213689482471
# Epoch 100/10000, Train Loss: 0.0806, Val Loss: 0.0620, Val Directional Accuracy: 0.6678
#
# EarlyStopping counter: 41 out of 100, current best is 0.6928213689482471
# Epoch 101/10000, Train Loss: 0.0805, Val Loss: 0.0630, Val Directional Accuracy: 0.6828
#
# EarlyStopping counter: 42 out of 100, current best is 0.6928213689482471
# Epoch 102/10000, Train Loss: 0.0807, Val Loss: 0.0768, Val Directional Accuracy: 0.6160
#
# EarlyStopping counter: 43 out of 100, current best is 0.6928213689482471
# Epoch 103/10000, Train Loss: 0.0782, Val Loss: 0.0657, Val Directional Accuracy: 0.6578
#
# EarlyStopping counter: 44 out of 100, current best is 0.6928213689482471
# Epoch 104/10000, Train Loss: 0.0759, Val Loss: 0.0655, Val Directional Accuracy: 0.6511
#
# EarlyStopping counter: 45 out of 100, current best is 0.6928213689482471
# Epoch 105/10000, Train Loss: 0.0856, Val Loss: 0.0789, Val Directional Accuracy: 0.6361
#
# EarlyStopping counter: 46 out of 100, current best is 0.6928213689482471
# Epoch 106/10000, Train Loss: 0.0817, Val Loss: 0.0656, Val Directional Accuracy: 0.6394
#
# EarlyStopping counter: 47 out of 100, current best is 0.6928213689482471
# Epoch 107/10000, Train Loss: 0.0789, Val Loss: 0.0975, Val Directional Accuracy: 0.5876
#
# EarlyStopping counter: 48 out of 100, current best is 0.6928213689482471
# Epoch 108/10000, Train Loss: 0.0830, Val Loss: 0.0711, Val Directional Accuracy: 0.6260
#
# EarlyStopping counter: 49 out of 100, current best is 0.6928213689482471
# Epoch 109/10000, Train Loss: 0.0817, Val Loss: 0.0655, Val Directional Accuracy: 0.6544
#
# EarlyStopping counter: 50 out of 100, current best is 0.6928213689482471
# Epoch 110/10000, Train Loss: 0.0792, Val Loss: 0.0798, Val Directional Accuracy: 0.5927
#
# EarlyStopping counter: 51 out of 100, current best is 0.6928213689482471
# Epoch 111/10000, Train Loss: 0.0877, Val Loss: 0.0990, Val Directional Accuracy: 0.5259
#
# EarlyStopping counter: 52 out of 100, current best is 0.6928213689482471
# Epoch 112/10000, Train Loss: 0.0812, Val Loss: 0.0736, Val Directional Accuracy: 0.6461
#
# EarlyStopping counter: 53 out of 100, current best is 0.6928213689482471
# Epoch 113/10000, Train Loss: 0.0888, Val Loss: 0.0890, Val Directional Accuracy: 0.5943
#
# EarlyStopping counter: 54 out of 100, current best is 0.6928213689482471
# Epoch 114/10000, Train Loss: 0.0808, Val Loss: 0.0639, Val Directional Accuracy: 0.6761
#
# EarlyStopping counter: 55 out of 100, current best is 0.6928213689482471
# Epoch 115/10000, Train Loss: 0.0810, Val Loss: 0.0688, Val Directional Accuracy: 0.6528
#
# EarlyStopping counter: 56 out of 100, current best is 0.6928213689482471
# Epoch 116/10000, Train Loss: 0.0849, Val Loss: 0.0653, Val Directional Accuracy: 0.6628
#
# EarlyStopping counter: 57 out of 100, current best is 0.6928213689482471
# Epoch 117/10000, Train Loss: 0.0788, Val Loss: 0.0738, Val Directional Accuracy: 0.6578
#
# EarlyStopping counter: 58 out of 100, current best is 0.6928213689482471
# Epoch 118/10000, Train Loss: 0.0767, Val Loss: 0.0641, Val Directional Accuracy: 0.6427
#
# EarlyStopping counter: 59 out of 100, current best is 0.6928213689482471
# Epoch 119/10000, Train Loss: 0.0793, Val Loss: 0.0696, Val Directional Accuracy: 0.6444
#
# EarlyStopping counter: 60 out of 100, current best is 0.6928213689482471
# Epoch 120/10000, Train Loss: 0.0820, Val Loss: 0.0777, Val Directional Accuracy: 0.6244
#
# EarlyStopping counter: 61 out of 100, current best is 0.6928213689482471
# Epoch 121/10000, Train Loss: 0.0855, Val Loss: 0.0840, Val Directional Accuracy: 0.5843
#
# EarlyStopping counter: 62 out of 100, current best is 0.6928213689482471
# Epoch 122/10000, Train Loss: 0.0855, Val Loss: 0.0635, Val Directional Accuracy: 0.6594
#
# EarlyStopping counter: 63 out of 100, current best is 0.6928213689482471
# Epoch 123/10000, Train Loss: 0.0771, Val Loss: 0.0704, Val Directional Accuracy: 0.6544
#
# EarlyStopping counter: 64 out of 100, current best is 0.6928213689482471
# Epoch 124/10000, Train Loss: 0.0799, Val Loss: 0.0746, Val Directional Accuracy: 0.6177
#
# EarlyStopping counter: 65 out of 100, current best is 0.6928213689482471
# Epoch 125/10000, Train Loss: 0.0787, Val Loss: 0.0700, Val Directional Accuracy: 0.6377
#
# EarlyStopping counter: 66 out of 100, current best is 0.6928213689482471
# Epoch 126/10000, Train Loss: 0.0806, Val Loss: 0.0707, Val Directional Accuracy: 0.6461
#
# EarlyStopping counter: 67 out of 100, current best is 0.6928213689482471
# Epoch 127/10000, Train Loss: 0.0847, Val Loss: 0.0740, Val Directional Accuracy: 0.6377
#
# EarlyStopping counter: 68 out of 100, current best is 0.6928213689482471
# Epoch 128/10000, Train Loss: 0.0825, Val Loss: 0.0766, Val Directional Accuracy: 0.6511
#
# EarlyStopping counter: 69 out of 100, current best is 0.6928213689482471
# Epoch 129/10000, Train Loss: 0.0804, Val Loss: 0.0726, Val Directional Accuracy: 0.6377
#
# EarlyStopping counter: 70 out of 100, current best is 0.6928213689482471
# Epoch 130/10000, Train Loss: 0.0772, Val Loss: 0.0679, Val Directional Accuracy: 0.6628
#
# EarlyStopping counter: 71 out of 100, current best is 0.6928213689482471
# Epoch 131/10000, Train Loss: 0.0800, Val Loss: 0.0616, Val Directional Accuracy: 0.6761
#
# EarlyStopping counter: 72 out of 100, current best is 0.6928213689482471
# Epoch 132/10000, Train Loss: 0.0807, Val Loss: 0.0759, Val Directional Accuracy: 0.6327
#
# EarlyStopping counter: 73 out of 100, current best is 0.6928213689482471
# Epoch 133/10000, Train Loss: 0.0776, Val Loss: 0.0613, Val Directional Accuracy: 0.6628
#
# EarlyStopping counter: 74 out of 100, current best is 0.6928213689482471
# Epoch 134/10000, Train Loss: 0.0895, Val Loss: 0.0879, Val Directional Accuracy: 0.5893
#
# EarlyStopping counter: 75 out of 100, current best is 0.6928213689482471
# Epoch 135/10000, Train Loss: 0.0835, Val Loss: 0.0802, Val Directional Accuracy: 0.6144
#
# EarlyStopping counter: 76 out of 100, current best is 0.6928213689482471
# Epoch 136/10000, Train Loss: 0.0827, Val Loss: 0.0789, Val Directional Accuracy: 0.6528
#
# EarlyStopping counter: 77 out of 100, current best is 0.6928213689482471
# Epoch 137/10000, Train Loss: 0.0820, Val Loss: 0.0747, Val Directional Accuracy: 0.6411
#
# EarlyStopping counter: 78 out of 100, current best is 0.6928213689482471
# Epoch 138/10000, Train Loss: 0.0764, Val Loss: 0.0677, Val Directional Accuracy: 0.6394
#
# EarlyStopping counter: 79 out of 100, current best is 0.6928213689482471
# Epoch 139/10000, Train Loss: 0.0807, Val Loss: 0.0841, Val Directional Accuracy: 0.6327
#
# EarlyStopping counter: 80 out of 100, current best is 0.6928213689482471
# Epoch 140/10000, Train Loss: 0.0797, Val Loss: 0.0695, Val Directional Accuracy: 0.6528
#
# EarlyStopping counter: 81 out of 100, current best is 0.6928213689482471
# Epoch 141/10000, Train Loss: 0.0854, Val Loss: 0.0810, Val Directional Accuracy: 0.6260
#
# EarlyStopping counter: 82 out of 100, current best is 0.6928213689482471
# Epoch 142/10000, Train Loss: 0.0856, Val Loss: 0.0863, Val Directional Accuracy: 0.6010
#
# EarlyStopping counter: 83 out of 100, current best is 0.6928213689482471
# Epoch 143/10000, Train Loss: 0.0813, Val Loss: 0.0630, Val Directional Accuracy: 0.6694
#
# EarlyStopping counter: 84 out of 100, current best is 0.6928213689482471
# Epoch 144/10000, Train Loss: 0.0747, Val Loss: 0.0672, Val Directional Accuracy: 0.6578
#
# EarlyStopping counter: 85 out of 100, current best is 0.6928213689482471
# Epoch 145/10000, Train Loss: 0.0753, Val Loss: 0.0891, Val Directional Accuracy: 0.5576
#
# EarlyStopping counter: 86 out of 100, current best is 0.6928213689482471
# Epoch 146/10000, Train Loss: 0.0821, Val Loss: 0.0901, Val Directional Accuracy: 0.6194
#
# EarlyStopping counter: 87 out of 100, current best is 0.6928213689482471
# Epoch 147/10000, Train Loss: 0.0817, Val Loss: 0.1180, Val Directional Accuracy: 0.5776
#
# EarlyStopping counter: 88 out of 100, current best is 0.6928213689482471
# Epoch 148/10000, Train Loss: 0.0822, Val Loss: 0.0664, Val Directional Accuracy: 0.6912
#
# EarlyStopping counter: 89 out of 100, current best is 0.6928213689482471
# Epoch 149/10000, Train Loss: 0.0822, Val Loss: 0.0738, Val Directional Accuracy: 0.6411
#
# EarlyStopping counter: 90 out of 100, current best is 0.6928213689482471
# Epoch 150/10000, Train Loss: 0.0829, Val Loss: 0.0745, Val Directional Accuracy: 0.6628
#
# EarlyStopping counter: 91 out of 100, current best is 0.6928213689482471
# Epoch 151/10000, Train Loss: 0.0808, Val Loss: 0.0744, Val Directional Accuracy: 0.6177
#
# EarlyStopping counter: 92 out of 100, current best is 0.6928213689482471
# Epoch 152/10000, Train Loss: 0.0771, Val Loss: 0.0780, Val Directional Accuracy: 0.6194
#
# EarlyStopping counter: 93 out of 100, current best is 0.6928213689482471
# Epoch 153/10000, Train Loss: 0.0827, Val Loss: 0.1104, Val Directional Accuracy: 0.5543
#
# EarlyStopping counter: 94 out of 100, current best is 0.6928213689482471
# Epoch 154/10000, Train Loss: 0.0803, Val Loss: 0.0606, Val Directional Accuracy: 0.6962
#
# Validation accuracy increased (0.692821 --> 0.696160).  Saving model...
# Epoch 155/10000, Train Loss: 0.0850, Val Loss: 0.0662, Val Directional Accuracy: 0.6845
#
# EarlyStopping counter: 1 out of 100, current best is 0.6961602671118531
# Epoch 156/10000, Train Loss: 0.0803, Val Loss: 0.0740, Val Directional Accuracy: 0.6661
#
# EarlyStopping counter: 2 out of 100, current best is 0.6961602671118531
# Epoch 157/10000, Train Loss: 0.0835, Val Loss: 0.0749, Val Directional Accuracy: 0.6194
#
# EarlyStopping counter: 3 out of 100, current best is 0.6961602671118531
# Epoch 158/10000, Train Loss: 0.0847, Val Loss: 0.0776, Val Directional Accuracy: 0.6611
#
# EarlyStopping counter: 4 out of 100, current best is 0.6961602671118531
# Epoch 159/10000, Train Loss: 0.0795, Val Loss: 0.0636, Val Directional Accuracy: 0.6444
#
# EarlyStopping counter: 5 out of 100, current best is 0.6961602671118531
# Epoch 160/10000, Train Loss: 0.0793, Val Loss: 0.0677, Val Directional Accuracy: 0.6678
#
# EarlyStopping counter: 6 out of 100, current best is 0.6961602671118531
# Epoch 161/10000, Train Loss: 0.0855, Val Loss: 0.0819, Val Directional Accuracy: 0.5860
#
# EarlyStopping counter: 7 out of 100, current best is 0.6961602671118531
# Epoch 162/10000, Train Loss: 0.0805, Val Loss: 0.0753, Val Directional Accuracy: 0.6227
#
# EarlyStopping counter: 8 out of 100, current best is 0.6961602671118531
# Epoch 163/10000, Train Loss: 0.0765, Val Loss: 0.0701, Val Directional Accuracy: 0.6327
#
# EarlyStopping counter: 9 out of 100, current best is 0.6961602671118531
# Epoch 164/10000, Train Loss: 0.0756, Val Loss: 0.0705, Val Directional Accuracy: 0.6394
#
# EarlyStopping counter: 10 out of 100, current best is 0.6961602671118531
# Epoch 165/10000, Train Loss: 0.0767, Val Loss: 0.0722, Val Directional Accuracy: 0.6528
#
# EarlyStopping counter: 11 out of 100, current best is 0.6961602671118531
# Epoch 166/10000, Train Loss: 0.0816, Val Loss: 0.0643, Val Directional Accuracy: 0.6678
#
# EarlyStopping counter: 12 out of 100, current best is 0.6961602671118531
# Epoch 167/10000, Train Loss: 0.0819, Val Loss: 0.1037, Val Directional Accuracy: 0.5659
#
# EarlyStopping counter: 13 out of 100, current best is 0.6961602671118531
# Epoch 168/10000, Train Loss: 0.0825, Val Loss: 0.0732, Val Directional Accuracy: 0.6093
#
# EarlyStopping counter: 14 out of 100, current best is 0.6961602671118531
# Epoch 169/10000, Train Loss: 0.0812, Val Loss: 0.0667, Val Directional Accuracy: 0.6528
#
# EarlyStopping counter: 15 out of 100, current best is 0.6961602671118531
# Epoch 170/10000, Train Loss: 0.0805, Val Loss: 0.0734, Val Directional Accuracy: 0.6494
#
# EarlyStopping counter: 16 out of 100, current best is 0.6961602671118531
# Epoch 171/10000, Train Loss: 0.0826, Val Loss: 0.1106, Val Directional Accuracy: 0.5710
#
# EarlyStopping counter: 17 out of 100, current best is 0.6961602671118531
# Epoch 172/10000, Train Loss: 0.0841, Val Loss: 0.0684, Val Directional Accuracy: 0.6678
#
# EarlyStopping counter: 18 out of 100, current best is 0.6961602671118531
# Epoch 173/10000, Train Loss: 0.0747, Val Loss: 0.0753, Val Directional Accuracy: 0.5977
#
# EarlyStopping counter: 19 out of 100, current best is 0.6961602671118531
# Epoch 174/10000, Train Loss: 0.0827, Val Loss: 0.0924, Val Directional Accuracy: 0.5960
#
# EarlyStopping counter: 20 out of 100, current best is 0.6961602671118531
# Epoch 175/10000, Train Loss: 0.0814, Val Loss: 0.0741, Val Directional Accuracy: 0.5993
#
# EarlyStopping counter: 21 out of 100, current best is 0.6961602671118531
# Epoch 176/10000, Train Loss: 0.0796, Val Loss: 0.0615, Val Directional Accuracy: 0.6745
#
# EarlyStopping counter: 22 out of 100, current best is 0.6961602671118531
# Epoch 177/10000, Train Loss: 0.0814, Val Loss: 0.0609, Val Directional Accuracy: 0.6611
#
# EarlyStopping counter: 23 out of 100, current best is 0.6961602671118531
# Epoch 178/10000, Train Loss: 0.0783, Val Loss: 0.0679, Val Directional Accuracy: 0.6661
#
# EarlyStopping counter: 24 out of 100, current best is 0.6961602671118531
# Epoch 179/10000, Train Loss: 0.0864, Val Loss: 0.0725, Val Directional Accuracy: 0.6260
#
# EarlyStopping counter: 25 out of 100, current best is 0.6961602671118531
# Epoch 180/10000, Train Loss: 0.0879, Val Loss: 0.0721, Val Directional Accuracy: 0.6444
#
# EarlyStopping counter: 26 out of 100, current best is 0.6961602671118531
# Epoch 181/10000, Train Loss: 0.0814, Val Loss: 0.0722, Val Directional Accuracy: 0.6411
#
# EarlyStopping counter: 27 out of 100, current best is 0.6961602671118531
# Epoch 182/10000, Train Loss: 0.0750, Val Loss: 0.0716, Val Directional Accuracy: 0.6377
#
# EarlyStopping counter: 28 out of 100, current best is 0.6961602671118531
# Epoch 183/10000, Train Loss: 0.0829, Val Loss: 0.0678, Val Directional Accuracy: 0.6711
#
# EarlyStopping counter: 29 out of 100, current best is 0.6961602671118531
# Epoch 184/10000, Train Loss: 0.0783, Val Loss: 0.0747, Val Directional Accuracy: 0.6194
#
# EarlyStopping counter: 30 out of 100, current best is 0.6961602671118531
# Epoch 185/10000, Train Loss: 0.0803, Val Loss: 0.0861, Val Directional Accuracy: 0.6160
#
# EarlyStopping counter: 31 out of 100, current best is 0.6961602671118531
# Epoch 186/10000, Train Loss: 0.0838, Val Loss: 0.0850, Val Directional Accuracy: 0.6077
#
# EarlyStopping counter: 32 out of 100, current best is 0.6961602671118531
# Epoch 187/10000, Train Loss: 0.0799, Val Loss: 0.0705, Val Directional Accuracy: 0.6661
#
# EarlyStopping counter: 33 out of 100, current best is 0.6961602671118531
# Epoch 188/10000, Train Loss: 0.0841, Val Loss: 0.0764, Val Directional Accuracy: 0.6227
#
# EarlyStopping counter: 34 out of 100, current best is 0.6961602671118531
# Epoch 189/10000, Train Loss: 0.0819, Val Loss: 0.0829, Val Directional Accuracy: 0.6227
#
# EarlyStopping counter: 35 out of 100, current best is 0.6961602671118531
# Epoch 190/10000, Train Loss: 0.0797, Val Loss: 0.1090, Val Directional Accuracy: 0.6177
#
# EarlyStopping counter: 36 out of 100, current best is 0.6961602671118531
# Epoch 191/10000, Train Loss: 0.0808, Val Loss: 0.1014, Val Directional Accuracy: 0.6093
#
# EarlyStopping counter: 37 out of 100, current best is 0.6961602671118531
# Epoch 192/10000, Train Loss: 0.0782, Val Loss: 0.0682, Val Directional Accuracy: 0.6277
#
# EarlyStopping counter: 38 out of 100, current best is 0.6961602671118531
# Epoch 193/10000, Train Loss: 0.0805, Val Loss: 0.0697, Val Directional Accuracy: 0.6077
#
# EarlyStopping counter: 39 out of 100, current best is 0.6961602671118531
# Epoch 194/10000, Train Loss: 0.0851, Val Loss: 0.0839, Val Directional Accuracy: 0.5810
#
# EarlyStopping counter: 40 out of 100, current best is 0.6961602671118531
# Epoch 195/10000, Train Loss: 0.0785, Val Loss: 0.0784, Val Directional Accuracy: 0.5743
#
# EarlyStopping counter: 41 out of 100, current best is 0.6961602671118531
# Epoch 196/10000, Train Loss: 0.0843, Val Loss: 0.0723, Val Directional Accuracy: 0.6578
#
# EarlyStopping counter: 42 out of 100, current best is 0.6961602671118531
# Epoch 197/10000, Train Loss: 0.0865, Val Loss: 0.0601, Val Directional Accuracy: 0.6895
#
# EarlyStopping counter: 43 out of 100, current best is 0.6961602671118531
# Epoch 198/10000, Train Loss: 0.0829, Val Loss: 0.0836, Val Directional Accuracy: 0.5860
#
# EarlyStopping counter: 44 out of 100, current best is 0.6961602671118531
# Epoch 199/10000, Train Loss: 0.0906, Val Loss: 0.0878, Val Directional Accuracy: 0.6277
#
# EarlyStopping counter: 45 out of 100, current best is 0.6961602671118531
# Epoch 200/10000, Train Loss: 0.0757, Val Loss: 0.0790, Val Directional Accuracy: 0.6294
#
# EarlyStopping counter: 46 out of 100, current best is 0.6961602671118531
# Epoch 201/10000, Train Loss: 0.0774, Val Loss: 0.1058, Val Directional Accuracy: 0.5876
#
# EarlyStopping counter: 47 out of 100, current best is 0.6961602671118531
# Epoch 202/10000, Train Loss: 0.0838, Val Loss: 0.1331, Val Directional Accuracy: 0.5359
#
# EarlyStopping counter: 48 out of 100, current best is 0.6961602671118531
# Epoch 203/10000, Train Loss: 0.0859, Val Loss: 0.0667, Val Directional Accuracy: 0.6594
#
# EarlyStopping counter: 49 out of 100, current best is 0.6961602671118531
# Epoch 204/10000, Train Loss: 0.0867, Val Loss: 0.0719, Val Directional Accuracy: 0.6611
#
# EarlyStopping counter: 50 out of 100, current best is 0.6961602671118531
# Epoch 205/10000, Train Loss: 0.0778, Val Loss: 0.0810, Val Directional Accuracy: 0.6344
#
# EarlyStopping counter: 51 out of 100, current best is 0.6961602671118531
# Epoch 206/10000, Train Loss: 0.0865, Val Loss: 0.0729, Val Directional Accuracy: 0.6127
#
# EarlyStopping counter: 52 out of 100, current best is 0.6961602671118531
# Epoch 207/10000, Train Loss: 0.0857, Val Loss: 0.0943, Val Directional Accuracy: 0.5843
#
# EarlyStopping counter: 53 out of 100, current best is 0.6961602671118531
# Epoch 208/10000, Train Loss: 0.0798, Val Loss: 0.0655, Val Directional Accuracy: 0.6444
#
# EarlyStopping counter: 54 out of 100, current best is 0.6961602671118531
# Epoch 209/10000, Train Loss: 0.0770, Val Loss: 0.0872, Val Directional Accuracy: 0.6060
#
# EarlyStopping counter: 55 out of 100, current best is 0.6961602671118531
# Epoch 210/10000, Train Loss: 0.0813, Val Loss: 0.0710, Val Directional Accuracy: 0.6227
#
# EarlyStopping counter: 56 out of 100, current best is 0.6961602671118531
# Epoch 211/10000, Train Loss: 0.0844, Val Loss: 0.0751, Val Directional Accuracy: 0.6110
#
# EarlyStopping counter: 57 out of 100, current best is 0.6961602671118531
# Epoch 212/10000, Train Loss: 0.0787, Val Loss: 0.0920, Val Directional Accuracy: 0.6110
#
# EarlyStopping counter: 58 out of 100, current best is 0.6961602671118531
# Epoch 213/10000, Train Loss: 0.0872, Val Loss: 0.0808, Val Directional Accuracy: 0.6344
#
# EarlyStopping counter: 59 out of 100, current best is 0.6961602671118531
# Epoch 214/10000, Train Loss: 0.0797, Val Loss: 0.0929, Val Directional Accuracy: 0.5726
#
# EarlyStopping counter: 60 out of 100, current best is 0.6961602671118531
# Epoch 215/10000, Train Loss: 0.0806, Val Loss: 0.0627, Val Directional Accuracy: 0.6544
#
# EarlyStopping counter: 61 out of 100, current best is 0.6961602671118531
# Epoch 216/10000, Train Loss: 0.0797, Val Loss: 0.0868, Val Directional Accuracy: 0.6043
#
# EarlyStopping counter: 62 out of 100, current best is 0.6961602671118531
# Epoch 217/10000, Train Loss: 0.0841, Val Loss: 0.0710, Val Directional Accuracy: 0.6344
#
# EarlyStopping counter: 63 out of 100, current best is 0.6961602671118531
# Epoch 218/10000, Train Loss: 0.0814, Val Loss: 0.1063, Val Directional Accuracy: 0.5876
#
# EarlyStopping counter: 64 out of 100, current best is 0.6961602671118531
# Epoch 219/10000, Train Loss: 0.0800, Val Loss: 0.0616, Val Directional Accuracy: 0.6528
#
# EarlyStopping counter: 65 out of 100, current best is 0.6961602671118531
# Epoch 220/10000, Train Loss: 0.0817, Val Loss: 0.1103, Val Directional Accuracy: 0.5426
#
# EarlyStopping counter: 66 out of 100, current best is 0.6961602671118531
# Epoch 221/10000, Train Loss: 0.0825, Val Loss: 0.0707, Val Directional Accuracy: 0.6311
#
# EarlyStopping counter: 67 out of 100, current best is 0.6961602671118531
# Epoch 222/10000, Train Loss: 0.0866, Val Loss: 0.0655, Val Directional Accuracy: 0.6528
#
# EarlyStopping counter: 68 out of 100, current best is 0.6961602671118531
# Epoch 223/10000, Train Loss: 0.0859, Val Loss: 0.0773, Val Directional Accuracy: 0.6010
#
# EarlyStopping counter: 69 out of 100, current best is 0.6961602671118531
# Epoch 224/10000, Train Loss: 0.0828, Val Loss: 0.0697, Val Directional Accuracy: 0.6511
#
# EarlyStopping counter: 70 out of 100, current best is 0.6961602671118531
# Epoch 225/10000, Train Loss: 0.0780, Val Loss: 0.0630, Val Directional Accuracy: 0.6578
#
# EarlyStopping counter: 71 out of 100, current best is 0.6961602671118531
# Epoch 226/10000, Train Loss: 0.0792, Val Loss: 0.0618, Val Directional Accuracy: 0.6511
#
# EarlyStopping counter: 72 out of 100, current best is 0.6961602671118531
# Epoch 227/10000, Train Loss: 0.0803, Val Loss: 0.0757, Val Directional Accuracy: 0.6327
#
# EarlyStopping counter: 73 out of 100, current best is 0.6961602671118531
# Epoch 228/10000, Train Loss: 0.0801, Val Loss: 0.0882, Val Directional Accuracy: 0.5526
#
# EarlyStopping counter: 74 out of 100, current best is 0.6961602671118531
# Epoch 229/10000, Train Loss: 0.0826, Val Loss: 0.0843, Val Directional Accuracy: 0.6077
#
# EarlyStopping counter: 75 out of 100, current best is 0.6961602671118531
# Epoch 230/10000, Train Loss: 0.0835, Val Loss: 0.0772, Val Directional Accuracy: 0.6444
#
# EarlyStopping counter: 76 out of 100, current best is 0.6961602671118531
# Epoch 231/10000, Train Loss: 0.0820, Val Loss: 0.0831, Val Directional Accuracy: 0.6010
#
# EarlyStopping counter: 77 out of 100, current best is 0.6961602671118531
# Epoch 232/10000, Train Loss: 0.0819, Val Loss: 0.0675, Val Directional Accuracy: 0.6611
#
# EarlyStopping counter: 78 out of 100, current best is 0.6961602671118531
# Epoch 233/10000, Train Loss: 0.0811, Val Loss: 0.0977, Val Directional Accuracy: 0.5459
#
# EarlyStopping counter: 79 out of 100, current best is 0.6961602671118531
# Epoch 234/10000, Train Loss: 0.0806, Val Loss: 0.0785, Val Directional Accuracy: 0.6010
#
# EarlyStopping counter: 80 out of 100, current best is 0.6961602671118531
# Epoch 235/10000, Train Loss: 0.0856, Val Loss: 0.0722, Val Directional Accuracy: 0.6277
#
# EarlyStopping counter: 81 out of 100, current best is 0.6961602671118531
# Epoch 236/10000, Train Loss: 0.0829, Val Loss: 0.0629, Val Directional Accuracy: 0.6795
#
# EarlyStopping counter: 82 out of 100, current best is 0.6961602671118531
# Epoch 237/10000, Train Loss: 0.0856, Val Loss: 0.0652, Val Directional Accuracy: 0.6461
#
# EarlyStopping counter: 83 out of 100, current best is 0.6961602671118531
# Epoch 238/10000, Train Loss: 0.0765, Val Loss: 0.0685, Val Directional Accuracy: 0.6344
#
# EarlyStopping counter: 84 out of 100, current best is 0.6961602671118531
# Epoch 239/10000, Train Loss: 0.0821, Val Loss: 0.1017, Val Directional Accuracy: 0.5659
#
# EarlyStopping counter: 85 out of 100, current best is 0.6961602671118531
# Epoch 240/10000, Train Loss: 0.0786, Val Loss: 0.0728, Val Directional Accuracy: 0.6461
#
# EarlyStopping counter: 86 out of 100, current best is 0.6961602671118531
# Epoch 241/10000, Train Loss: 0.0825, Val Loss: 0.0688, Val Directional Accuracy: 0.6444
#
# EarlyStopping counter: 87 out of 100, current best is 0.6961602671118531
# Epoch 242/10000, Train Loss: 0.0825, Val Loss: 0.0669, Val Directional Accuracy: 0.6745
#
# EarlyStopping counter: 88 out of 100, current best is 0.6961602671118531
# Epoch 243/10000, Train Loss: 0.0874, Val Loss: 0.0829, Val Directional Accuracy: 0.6093
#
# EarlyStopping counter: 89 out of 100, current best is 0.6961602671118531
# Epoch 244/10000, Train Loss: 0.0851, Val Loss: 0.0656, Val Directional Accuracy: 0.6594
#
# EarlyStopping counter: 90 out of 100, current best is 0.6961602671118531
# Epoch 245/10000, Train Loss: 0.0851, Val Loss: 0.0915, Val Directional Accuracy: 0.5843
#
# EarlyStopping counter: 91 out of 100, current best is 0.6961602671118531
# Epoch 246/10000, Train Loss: 0.0854, Val Loss: 0.0730, Val Directional Accuracy: 0.6427
#
# EarlyStopping counter: 92 out of 100, current best is 0.6961602671118531
# Epoch 247/10000, Train Loss: 0.0819, Val Loss: 0.0661, Val Directional Accuracy: 0.6578
#
# EarlyStopping counter: 93 out of 100, current best is 0.6961602671118531
# Epoch 248/10000, Train Loss: 0.0798, Val Loss: 0.0808, Val Directional Accuracy: 0.6077
#
# EarlyStopping counter: 94 out of 100, current best is 0.6961602671118531
# Epoch 249/10000, Train Loss: 0.0793, Val Loss: 0.0779, Val Directional Accuracy: 0.6511
#
# EarlyStopping counter: 95 out of 100, current best is 0.6961602671118531
# Epoch 250/10000, Train Loss: 0.0851, Val Loss: 0.0925, Val Directional Accuracy: 0.6010
#
# EarlyStopping counter: 96 out of 100, current best is 0.6961602671118531
# Epoch 251/10000, Train Loss: 0.0782, Val Loss: 0.0673, Val Directional Accuracy: 0.6594
#
# EarlyStopping counter: 97 out of 100, current best is 0.6961602671118531
# Epoch 252/10000, Train Loss: 0.0797, Val Loss: 0.0957, Val Directional Accuracy: 0.6010
#
# EarlyStopping counter: 98 out of 100, current best is 0.6961602671118531
# Epoch 253/10000, Train Loss: 0.0833, Val Loss: 0.0863, Val Directional Accuracy: 0.5943
#
# EarlyStopping counter: 99 out of 100, current best is 0.6961602671118531
# Epoch 254/10000, Train Loss: 0.0798, Val Loss: 0.0854, Val Directional Accuracy: 0.6144
#
# EarlyStopping counter: 100 out of 100, current best is 0.6961602671118531
# Early stopping triggered. Training stopped.

# %%
model.load_state_dict(torch.load('best_model.pth', weights_only=True))

model.eval()
test_loss = 0.0
test_directional_accuracy = 0.0
with torch.no_grad():
    for sequences, labels in test_loader:
        sequences = sequences.to(device)
        labels = labels.to(device)

        outputs = model(sequences)
        outputs = outputs.squeeze()

        loss = criterion(outputs, labels)
        test_loss += loss.item() * labels.size(0)

        # Compute directional accuracy
        prev_close = sequences[:, -1, 0]
        true_diff = labels - prev_close
        pred_diff = outputs - prev_close
        correct_direction = torch.eq(torch.sign(true_diff), torch.sign(pred_diff)).float()
        test_directional_accuracy += correct_direction.sum().item()

avg_test_loss = test_loss / len(test_loader.dataset)
avg_test_accuracy = test_directional_accuracy / len(test_loader.dataset)

print(f"Test Loss: {avg_test_loss:.4f}, Test Directional Accuracy: {avg_test_accuracy:.4f}")
# Out:
# Test Loss: 0.0662, Test Directional Accuracy: 0.6600
